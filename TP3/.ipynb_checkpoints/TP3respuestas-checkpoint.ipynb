# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

#CARGAR LAS BASES DE DATOS
os.chdir('/Users/trinimoran/Documents/Ciencia de Datos/CC408-T13/TP3/data')
# os.chdir('C:/Flor/UDESA/Primavera 2024/Ciencia de datos/TP3')

#CAMBIEN ACA SUS CAMINOS
#os.chdir('C:/Users/Nacha/OneDrive/Desktop/Anaconda')

# %% [markdown]
# # PARTE 1

# %%
#Primero cargamos las bases de datos
eph_04 = pd.read_excel('usu_individual_T124.xlsx')
eph_24 = pd.read_stata('Individual_t104.dta')
eph_04
eph_24
# Out:
#          CODUSU  nro_hogar componente  h15    ano4       trimestre  \
# 0      125098          1.0        1.0   Sí  2004.0  1er. Trimestre
# 1      125397          1.0        1.0   Sí  2004.0  1er. Trimestre
# 2      125515          1.0        1.0   Sí  2004.0  1er. Trimestre
# 3      125558          1.0        1.0   Sí  2004.0  1er. Trimestre
# 4      125558          1.0        2.0   Sí  2004.0  1er. Trimestre
# ...         ...        ...        ...  ...     ...             ...
# 45284  285733          1.0        1.0   Sí  2004.0  1er. Trimestre
# 45285  285733          1.0        2.0   Sí  2004.0  1er. Trimestre
# 45286  285733          1.0        3.0   Sí  2004.0  1er. Trimestre
# 45287  285733          1.0        4.0  0.0  2004.0  1er. Trimestre
# 45288  285733          1.0        5.0  0.0  2004.0  1er. Trimestre
#
#                   region mas_500              aglomerado  pondera  ... deccfr  \
# 0      Gran Buenos Aires       S  Ciudad de Buenos Aires   1299.0  ...     07
# 1      Gran Buenos Aires       S  Ciudad de Buenos Aires   2018.0  ...     00
# 2      Gran Buenos Aires       S  Ciudad de Buenos Aires   1486.0  ...     07
# 3      Gran Buenos Aires       S  Ciudad de Buenos Aires   1674.0  ...     08
# 4      Gran Buenos Aires       S  Ciudad de Buenos Aires   1674.0  ...     08
# ...                  ...     ...                     ...      ...  ...    ...
# 45284         Patagónica       N    Ushuaia - Río Grande    123.0  ...     09
# 45285         Patagónica       N    Ushuaia - Río Grande    123.0  ...     09
# 45286         Patagónica       N    Ushuaia - Río Grande    123.0  ...     09
# 45287         Patagónica       N    Ushuaia - Río Grande    123.0  ...     09
# 45288         Patagónica       N    Ushuaia - Río Grande    123.0  ...     09
#
#       ideccfr rdeccfr gdeccfr pdeccfr adeccfr pj1_1 pj2_1 pj3_1 idimpp
# 0                  06      06              04   0.0   0.0   0.0  00000
# 1                  00      00              00   0.0   0.0   0.0  00000
# 2                  07      07              05   0.0   0.0   0.0  00020
# 3                  08      08              06   0.0   0.0   0.0  00000
# 4                  08      08              06   0.0   0.0   0.0  00000
# ...       ...     ...     ...     ...     ...   ...   ...   ...    ...
# 45284      09      08              09      07   0.0   0.0   0.0  00000
# 45285      09      08              09      07   0.0   0.0   0.0  00000
# 45286      09      08              09      07   0.0   0.0   0.0  00000
# 45287      09      08              09      07   0.0   0.0   0.0  00000
# 45288      09      08              09      07   0.0   0.0   0.0  00000
#
# [45289 rows x 176 columns]

# %%
# Para poder unificar las bases, cambiamos los nombres de las columnas a mayúsculas para que queden iguales
eph_04.columns = eph_04.columns.str.upper()
eph_24.columns = eph_24.columns.str.upper()

# %% [markdown]
# EJERCICIO 2
# A) Eliminen todas las observaciones que no corresponden a los aglomerados de Ciudad Autónoma de Buenos Aires o Gran Buenos Aires y unan ambos trimestres en una sola base

# %%
#Como ambos DataFrame tiene diferente codificación, los limpiamos por separado según las categorías correspondientes
# Filtrar para CABA (32) y GBA (33) en 2004
eph_04_cleaned = eph_04.drop(eph_04[~eph_04['AGLOMERADO'].isin([32, 33])].index)

# Filtrar para CABA y GBA en 2024 utilizando nombres de aglomerados
eph_24_cleaned = eph_24.drop(eph_24[~eph_24['AGLOMERADO'].isin(['Ciudad de Buenos Aires', 'Partidos del GBA'])].index)

#Esto es para comprobar que quedan datos de ambos años en el nuevo DataFrame
print("Datos 2004 después de filtrar:", eph_04_cleaned.shape[0])
print("Datos 2024 después de filtrar:", eph_24_cleaned.shape[0])

# Concatenar los DataFrames limpios
eph_combined = pd.concat([eph_04_cleaned, eph_24_cleaned], ignore_index=True)

# Verificar la forma del nuevo DataFrame
print("Cantidad de filas en eph_combined después de concatenar:", eph_combined.shape[0])
print("Primeras filas de eph_combined:\n", eph_combined.head())


# Vemos la nueva base 
#print(eph_combined.head())
eph_combined
# Out:
# Datos 2004 después de filtrar: 7051
# Datos 2024 después de filtrar: 7647
# Cantidad de filas en eph_combined después de concatenar: 14698
# Primeras filas de eph_combined:
#                            CODUSU    ANO4 TRIMESTRE  NRO_HOGAR COMPONENTE H15  \
# 0  TQRMNOSUWHLKMUCDEIJAH00855260  2024.0         1        1.0          1   1
# 1  TQRMNOSUWHLKMUCDEIJAH00855260  2024.0         1        1.0          2   1
# 2  TQRMNOSUWHLKMUCDEIJAH00855260  2024.0         1        1.0          3   1
# 3  TQSMNORWVHLLKQCDEIJAH00856914  2024.0         1        1.0          1   1
# 4  TQRMNOPQQHLOLRCDEIJAH00855133  2024.0         1        1.0          1   1
#
#   REGION MAS_500 AGLOMERADO  PONDERA  ... IDECCFR RDECCFR GDECCFR PDECCFR  \
# 0      1       S         33   1810.0  ...     NaN      12    12.0     NaN
# 1      1       S         33   1810.0  ...     NaN      12    12.0     NaN
# 2      1       S         33   1810.0  ...     NaN      12    12.0     NaN
# 3      1       S         33   2368.0  ...     NaN       9     9.0     NaN
# 4      1       S         33   1223.0  ...     NaN      12    12.0     NaN
#
#   ADECCFR  PONDIH PJ1_1 PJ2_1 PJ3_1 IDIMPP
# 0      12     0.0   NaN   NaN   NaN    NaN
# 1      12     0.0   NaN   NaN   NaN    NaN
# 2      12     0.0   NaN   NaN   NaN    NaN
# 3       9  3324.0   NaN   NaN   NaN    NaN
# 4      12     0.0   NaN   NaN   NaN    NaN
#
# [5 rows x 181 columns]
#                               CODUSU    ANO4       TRIMESTRE  NRO_HOGAR  \
# 0      TQRMNOSUWHLKMUCDEIJAH00855260  2024.0               1        1.0
# 1      TQRMNOSUWHLKMUCDEIJAH00855260  2024.0               1        1.0
# 2      TQRMNOSUWHLKMUCDEIJAH00855260  2024.0               1        1.0
# 3      TQSMNORWVHLLKQCDEIJAH00856914  2024.0               1        1.0
# 4      TQRMNOPQQHLOLRCDEIJAH00855133  2024.0               1        1.0
# ...                              ...     ...             ...        ...
# 14693                       288171    2004.0  1er. Trimestre        1.0
# 14694                       288405    2004.0  1er. Trimestre        1.0
# 14695                       288405    2004.0  1er. Trimestre        1.0
# 14696                       288405    2004.0  1er. Trimestre        1.0
# 14697                       288405    2004.0  1er. Trimestre        1.0
#
#       COMPONENTE  H15             REGION MAS_500        AGLOMERADO  PONDERA  \
# 0              1    1                  1       S                33   1810.0
# 1              2    1                  1       S                33   1810.0
# 2              3    1                  1       S                33   1810.0
# 3              1    1                  1       S                33   2368.0
# 4              1    1                  1       S                33   1223.0
# ...          ...  ...                ...     ...               ...      ...
# 14693        3.0  0.0  Gran Buenos Aires       S  Partidos del GBA   1454.0
# 14694        1.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
# 14695        2.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
# 14696        3.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
# 14697        4.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
#
#        ... IDECCFR RDECCFR GDECCFR PDECCFR ADECCFR  PONDIH PJ1_1 PJ2_1 PJ3_1  \
# 0      ...     NaN      12    12.0     NaN      12     0.0   NaN   NaN   NaN
# 1      ...     NaN      12    12.0     NaN      12     0.0   NaN   NaN   NaN
# 2      ...     NaN      12    12.0     NaN      12     0.0   NaN   NaN   NaN
# 3      ...     NaN       9     9.0     NaN       9  3324.0   NaN   NaN   NaN
# 4      ...     NaN      12    12.0     NaN      12     0.0   NaN   NaN   NaN
# ...    ...     ...     ...     ...     ...     ...     ...   ...   ...   ...
# 14693  ...              08      08              09     NaN   0.0   0.0   0.0
# 14694  ...              02      02              02     NaN   0.0   0.0   0.0
# 14695  ...              02      02              02     NaN   0.0   0.0   0.0
# 14696  ...              02      02              02     NaN   0.0   0.0   0.0
# 14697  ...              02      02              02     NaN   0.0   0.0   0.0
#
#       IDIMPP
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 14693  00000
# 14694  00000
# 14695  00000
# 14696  00000
# 14697  00000
#
# [14698 rows x 181 columns]

# %%
# Imprimir las columnas como una lista para poder ver los nombres de todas
print(list(eph_combined.columns))
# Out:
# ['CODUSU', 'ANO4', 'TRIMESTRE', 'NRO_HOGAR', 'COMPONENTE', 'H15', 'REGION', 'MAS_500', 'AGLOMERADO', 'PONDERA', 'CH03', 'CH04', 'CH05', 'CH06', 'CH07', 'CH08', 'CH09', 'CH10', 'CH11', 'CH12', 'CH13', 'CH14', 'CH15', 'CH15_COD', 'CH16', 'CH16_COD', 'NIVEL_ED', 'ESTADO', 'CAT_OCUP', 'CAT_INAC', 'IMPUTA', 'PP02C1', 'PP02C2', 'PP02C3', 'PP02C4', 'PP02C5', 'PP02C6', 'PP02C7', 'PP02C8', 'PP02E', 'PP02H', 'PP02I', 'PP03C', 'PP03D', 'PP3E_TOT', 'PP3F_TOT', 'PP03G', 'PP03H', 'PP03I', 'PP03J', 'INTENSI', 'PP04A', 'PP04B_COD', 'PP04B1', 'PP04B2', 'PP04B3_MES', 'PP04B3_ANO', 'PP04B3_DIA', 'PP04C', 'PP04C99', 'PP04D_COD', 'PP04G', 'PP05B2_MES', 'PP05B2_ANO', 'PP05B2_DIA', 'PP05C_1', 'PP05C_2', 'PP05C_3', 'PP05E', 'PP05F', 'PP05H', 'PP06A', 'PP06C', 'PP06D', 'PP06E', 'PP06H', 'PP07A', 'PP07C', 'PP07D', 'PP07E', 'PP07F1', 'PP07F2', 'PP07F3', 'PP07F4', 'PP07F5', 'PP07G1', 'PP07G2', 'PP07G3', 'PP07G4', 'PP07G_59', 'PP07H', 'PP07I', 'PP07J', 'PP07K', 'PP08D1', 'PP08D4', 'PP08F1', 'PP08F2', 'PP08J1', 'PP08J2', 'PP08J3', 'PP09A', 'PP09A_ESP', 'PP09B', 'PP09C', 'PP09C_ESP', 'PP10A', 'PP10C', 'PP10D', 'PP10E', 'PP11A', 'PP11B_COD', 'PP11B1', 'PP11B2_MES', 'PP11B2_ANO', 'PP11B2_DIA', 'PP11C', 'PP11C99', 'PP11D_COD', 'PP11G_ANO', 'PP11G_MES', 'PP11G_DIA', 'PP11L', 'PP11L1', 'PP11M', 'PP11N', 'PP11O', 'PP11P', 'PP11Q', 'PP11R', 'PP11S', 'PP11T', 'P21', 'DECOCUR', 'IDECOCUR', 'RDECOCUR', 'GDECOCUR', 'PDECOCUR', 'ADECOCUR', 'PONDIIO', 'TOT_P12', 'P47T', 'DECINDR', 'IDECINDR', 'RDECINDR', 'GDECINDR', 'PDECINDR', 'ADECINDR', 'PONDII', 'V2_M', 'V3_M', 'V4_M', 'V5_M', 'V8_M', 'V9_M', 'V10_M', 'V11_M', 'V12_M', 'V18_M', 'V19_AM', 'V21_M', 'T_VI', 'ITF', 'DECIFR', 'IDECIFR', 'RDECIFR', 'GDECIFR', 'PDECIFR', 'ADECIFR', 'IPCF', 'DECCFR', 'IDECCFR', 'RDECCFR', 'GDECCFR', 'PDECCFR', 'ADECCFR', 'PONDIH', 'PJ1_1', 'PJ2_1', 'PJ3_1', 'IDIMPP']

# %% [markdown]
# B. Si hay observaciones con valores que no tienen sentido, descártenlas (por ejemplo, ingresos y edades negativos). Expliquen las decisiones tomadas.

# %%
# Eliminamos las observaciones con datos que no tienen sentido 
# CH06: edad
# PP03D: cantidad de ocupaciones 
# PP08D1: Monto por sueldos / jornales, salario familiar, horas extras, otras bonificaciones habituales y tickets, vales o similares percibidos en el mes de referencia 
# P21: MONTO DE INGRESO DE LA OCUPACIÓN PRINCIPAL 
# Convertir las columnas relevantes a tipo numérico
cols_to_convert = ['CH06', 'PP03D', 'PP08D1', 'P21']
eph_combined[cols_to_convert] = eph_combined[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# Eliminar filas con NaN en las columnas relevantes
eph_combined.dropna(subset=cols_to_convert, inplace=True)

# Eliminamos las observaciones con datos que no tienen sentido 
eph_combined.drop(
    eph_combined[
        (eph_combined['CH06'] < 0) | 
        (eph_combined['PP03D'] < 0) |  
        (eph_combined['PP08D1'] < 0) | 
        (eph_combined['P21'] < 0)
    ].index, 
    inplace=True)

# Imprimir la cantidad de datos restantes después de la limpieza
print("Cantidad de datos después de la limpieza:", len(eph_combined))

#acá tenemos que redactar la justificación, no puse más porque no terminamos más si controlamos todo todo, si ven otra relevante o quieren sacar alguna háganlo
# Out:
# Cantidad de datos después de la limpieza: 9790

# %% [markdown]
# C. Una vez hecha esa limpieza, realicen un gráfico de barras mostrando la composición por sexo para 2004 y 2024. Comenten los resultados.

# %%
# Convertimos 'ano4' a tipo entero para eliminar los decimales y asegurar que todos los valores sean consistentes
eph_combined['ANO4'] = eph_combined['ANO4'].astype(float).astype(int)
eph_combined
# Out:
#                               CODUSU  ANO4       TRIMESTRE  NRO_HOGAR  \
# 0      TQRMNOSUWHLKMUCDEIJAH00855260  2024               1        1.0
# 3      TQSMNORWVHLLKQCDEIJAH00856914  2024               1        1.0
# 7      TQRMNOPTWHJLQRCDEIJAH00795141  2024               1        1.0
# 17     TQRMNOTPRHMOQQCDEIJAH00807721  2024               1        1.0
# 19     TQRMNOQURHKLSPCDEIJAH00856901  2024               1        1.0
# ...                              ...   ...             ...        ...
# 14693                       288171    2004  1er. Trimestre        1.0
# 14694                       288405    2004  1er. Trimestre        1.0
# 14695                       288405    2004  1er. Trimestre        1.0
# 14696                       288405    2004  1er. Trimestre        1.0
# 14697                       288405    2004  1er. Trimestre        1.0
#
#       COMPONENTE  H15             REGION MAS_500        AGLOMERADO  PONDERA  \
# 0              1    1                  1       S                33   1810.0
# 3              1    1                  1       S                33   2368.0
# 7              1    1                  1       S                33   1682.0
# 17             1    1                  1       S                33   1494.0
# 19             1    1                  1       S                33   2958.0
# ...          ...  ...                ...     ...               ...      ...
# 14693        3.0  0.0  Gran Buenos Aires       S  Partidos del GBA   1454.0
# 14694        1.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
# 14695        2.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
# 14696        3.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
# 14697        4.0   Sí  Gran Buenos Aires       S  Partidos del GBA   1673.0
#
#        ... IDECCFR RDECCFR GDECCFR  PDECCFR ADECCFR  PONDIH PJ1_1 PJ2_1 PJ3_1  \
# 0      ...     NaN      12    12.0      NaN      12     0.0   NaN   NaN   NaN
# 3      ...     NaN       9     9.0      NaN       9  3324.0   NaN   NaN   NaN
# 7      ...     NaN      10    10.0      NaN      10  2575.0   NaN   NaN   NaN
# 17     ...     NaN       8     8.0      NaN       9  1750.0   NaN   NaN   NaN
# 19     ...     NaN      12    12.0      NaN      12     0.0   NaN   NaN   NaN
# ...    ...     ...     ...     ...      ...     ...     ...   ...   ...   ...
# 14693  ...              08      08               09     NaN   0.0   0.0   0.0
# 14694  ...              02      02               02     NaN   0.0   0.0   0.0
# 14695  ...              02      02               02     NaN   0.0   0.0   0.0
# 14696  ...              02      02               02     NaN   0.0   0.0   0.0
# 14697  ...              02      02               02     NaN   0.0   0.0   0.0
#
#       IDIMPP
# 0        NaN
# 3        NaN
# 7        NaN
# 17       NaN
# 19       NaN
# ...      ...
# 14693  00000
# 14694  00000
# 14695  00000
# 14696  00000
# 14697  00000
#
# [9790 rows x 181 columns]

# %%
# Verificamos si hay datos en eph_combined para los años 2004 y 2024
print("Datos originales para 2004:\n", eph_combined[eph_combined['ANO4'] == 2004])
print("Datos originales para 2024:\n", eph_combined[eph_combined['ANO4'] == 2024])
# Out:
# Datos originales para 2004:
#           CODUSU  ANO4       TRIMESTRE  NRO_HOGAR COMPONENTE  H15  \
# 7051   125098    2004  1er. Trimestre        1.0        1.0   Sí
# 7052   125397    2004  1er. Trimestre        1.0        1.0   Sí
# 7053   125515    2004  1er. Trimestre        1.0        1.0   Sí
# 7054   125558    2004  1er. Trimestre        1.0        1.0   Sí
# 7055   125558    2004  1er. Trimestre        1.0        2.0   Sí
# ...         ...   ...             ...        ...        ...  ...
# 14693  288171    2004  1er. Trimestre        1.0        3.0  0.0
# 14694  288405    2004  1er. Trimestre        1.0        1.0   Sí
# 14695  288405    2004  1er. Trimestre        1.0        2.0   Sí
# 14696  288405    2004  1er. Trimestre        1.0        3.0   Sí
# 14697  288405    2004  1er. Trimestre        1.0        4.0   Sí
#
#                   REGION MAS_500              AGLOMERADO  PONDERA  ...  \
# 7051   Gran Buenos Aires       S  Ciudad de Buenos Aires   1299.0  ...
# 7052   Gran Buenos Aires       S  Ciudad de Buenos Aires   2018.0  ...
# 7053   Gran Buenos Aires       S  Ciudad de Buenos Aires   1486.0  ...
# 7054   Gran Buenos Aires       S  Ciudad de Buenos Aires   1674.0  ...
# 7055   Gran Buenos Aires       S  Ciudad de Buenos Aires   1674.0  ...
# ...                  ...     ...                     ...      ...  ...
# 14693  Gran Buenos Aires       S        Partidos del GBA   1454.0  ...
# 14694  Gran Buenos Aires       S        Partidos del GBA   1673.0  ...
# 14695  Gran Buenos Aires       S        Partidos del GBA   1673.0  ...
# 14696  Gran Buenos Aires       S        Partidos del GBA   1673.0  ...
# 14697  Gran Buenos Aires       S        Partidos del GBA   1673.0  ...
#
#       IDECCFR RDECCFR GDECCFR  PDECCFR ADECCFR PONDIH PJ1_1 PJ2_1 PJ3_1 IDIMPP
# 7051               06      06               04    NaN   0.0   0.0   0.0  00000
# 7052               00      00               00    NaN   0.0   0.0   0.0  00000
# 7053               07      07               05    NaN   0.0   0.0   0.0  00020
# 7054               08      08               06    NaN   0.0   0.0   0.0  00000
# 7055               08      08               06    NaN   0.0   0.0   0.0  00000
# ...       ...     ...     ...      ...     ...    ...   ...   ...   ...    ...
# 14693              08      08               09    NaN   0.0   0.0   0.0  00000
# 14694              02      02               02    NaN   0.0   0.0   0.0  00000
# 14695              02      02               02    NaN   0.0   0.0   0.0  00000
# 14696              02      02               02    NaN   0.0   0.0   0.0  00000
# 14697              02      02               02    NaN   0.0   0.0   0.0  00000
#
# [7512 rows x 181 columns]
# Datos originales para 2024:
#                               CODUSU  ANO4 TRIMESTRE  NRO_HOGAR COMPONENTE H15  \
# 0     TQRMNOSUWHLKMUCDEIJAH00855260  2024         1        1.0          1   1
# 3     TQSMNORWVHLLKQCDEIJAH00856914  2024         1        1.0          1   1
# 7     TQRMNOPTWHJLQRCDEIJAH00795141  2024         1        1.0          1   1
# 17    TQRMNOTPRHMOQQCDEIJAH00807721  2024         1        1.0          1   1
# 19    TQRMNOQURHKLSPCDEIJAH00856901  2024         1        1.0          1   1
# ...                             ...   ...       ...        ...        ...  ..
# 7035  TQRMNORWVHLKOPCDEIIAD00861660  2024         1        1.0          1   1
# 7036  TQRMNORWVHLKOPCDEIIAD00861660  2024         1        1.0          2   1
# 7037  TQRMNORWVHLKOPCDEIIAD00861660  2024         1        1.0          3   1
# 7041  TQRMNOPSYHJLOQCDEIIAD00794774  2024         1        1.0          1   1
# 7046  TQRMNOPUQHKMKNCDEIJAH00861661  2024         1        1.0          1   1
#
#      REGION MAS_500 AGLOMERADO  PONDERA  ... IDECCFR RDECCFR GDECCFR  PDECCFR  \
# 0         1       S         33   1810.0  ...     NaN      12    12.0      NaN
# 3         1       S         33   2368.0  ...     NaN       9     9.0      NaN
# 7         1       S         33   1682.0  ...     NaN      10    10.0      NaN
# 17        1       S         33   1494.0  ...     NaN       8     8.0      NaN
# 19        1       S         33   2958.0  ...     NaN      12    12.0      NaN
# ...     ...     ...        ...      ...  ...     ...     ...     ...      ...
# 7035      1       S         32    590.0  ...     NaN      12    12.0      NaN
# 7036      1       S         32    590.0  ...     NaN      12    12.0      NaN
# 7037      1       S         32    590.0  ...     NaN      12    12.0      NaN
# 7041      1       S         32   1376.0  ...     NaN      10    10.0      NaN
# 7046      1       S         33   3410.0  ...     NaN      12    12.0      NaN
#
#      ADECCFR  PONDIH PJ1_1 PJ2_1 PJ3_1 IDIMPP
# 0         12     0.0   NaN   NaN   NaN    NaN
# 3          9  3324.0   NaN   NaN   NaN    NaN
# 7         10  2575.0   NaN   NaN   NaN    NaN
# 17         9  1750.0   NaN   NaN   NaN    NaN
# 19        12     0.0   NaN   NaN   NaN    NaN
# ...      ...     ...   ...   ...   ...    ...
# 7035      12     0.0   NaN   NaN   NaN    NaN
# 7036      12     0.0   NaN   NaN   NaN    NaN
# 7037      12     0.0   NaN   NaN   NaN    NaN
# 7041      10  1781.0   NaN   NaN   NaN    NaN
# 7046      12     0.0   NaN   NaN   NaN    NaN
#
# [2278 rows x 181 columns]

# %%
# Filtramos los datos
datos_2004 = eph_combined[eph_combined['ANO4'] == 2004]
datos_2024 = eph_combined[eph_combined['ANO4'] == 2024]

# Verificamos cuántos registros hay después del filtrado
print(f"Registros 2004: {len(datos_2004)}")
print(f"Registros 2024: {len(datos_2024)}")
# Out:
# Registros 2004: 7512
# Registros 2024: 2278

# %%
# Verificamos si hay datos en eph_combined para los años 2004 y 2024
print("Datos originales para 2004:\n", eph_combined[eph_combined['ANO4'] == '2004'])
print("Datos originales para 2024:\n", eph_combined[eph_combined['ANO4'] == '2024'])

# Filtramos los datos
datos_2004 = eph_combined[eph_combined['ANO4'] == 2004]
datos_2024 = eph_combined[eph_combined['ANO4'] == 2024]

# Verificamos cuántos registros hay después del filtrado
print(f"Registros 2004: {len(datos_2004)}")
print(f"Registros 2024: {len(datos_2024)}")

# Contamos la cantidad de personas por sexo en cada año
composicion_2004 = datos_2004['CH04'].value_counts()
composicion_2024 = datos_2024['CH04'].value_counts()

# Imprimir los conteos para verificar si hay datos
print("Composición 2004:\n", composicion_2004)
print("Composición 2024:\n", composicion_2024)

# Creamos un DataFrame para graficar más fácil
df_composicion = pd.DataFrame({
    '2004': composicion_2004,
    '2024': composicion_2024
}).fillna(0)  # Rellenamos con 0 para evitar problemas al graficar

# Verificamos el DataFrame
print("DataFrame de composición:\n", df_composicion)

# Verificamos que hay datos antes de graficar
if not df_composicion.empty and df_composicion.sum().sum() > 0:
    # Crear gráfico de barras
    df_composicion.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'salmon'])
    plt.title('Composición por Sexo en 2004 y 2024')
    plt.xlabel('Sexo (1 = Varón, 2 = Mujer)')
    plt.ylabel('Cantidad de Personas')
    plt.xticks(ticks=[0, 1], labels=['1', '2'], rotation=0)  # Mostrar los códigos en el eje X
    plt.legend(title='Año')
    plt.grid(axis='y')
    plt.tight_layout()  # Ajustar el gráfico
    plt.show()
else:
    print("No hay datos para graficar.")
# Out:
# Datos originales para 2004:
#  Empty DataFrame
# Columns: [CODUSU, ANO4, TRIMESTRE, NRO_HOGAR, COMPONENTE, H15, REGION, MAS_500, AGLOMERADO, PONDERA, CH03, CH04, CH05, CH06, CH07, CH08, CH09, CH10, CH11, CH12, CH13, CH14, CH15, CH15_COD, CH16, CH16_COD, NIVEL_ED, ESTADO, CAT_OCUP, CAT_INAC, IMPUTA, PP02C1, PP02C2, PP02C3, PP02C4, PP02C5, PP02C6, PP02C7, PP02C8, PP02E, PP02H, PP02I, PP03C, PP03D, PP3E_TOT, PP3F_TOT, PP03G, PP03H, PP03I, PP03J, INTENSI, PP04A, PP04B_COD, PP04B1, PP04B2, PP04B3_MES, PP04B3_ANO, PP04B3_DIA, PP04C, PP04C99, PP04D_COD, PP04G, PP05B2_MES, PP05B2_ANO, PP05B2_DIA, PP05C_1, PP05C_2, PP05C_3, PP05E, PP05F, PP05H, PP06A, PP06C, PP06D, PP06E, PP06H, PP07A, PP07C, PP07D, PP07E, PP07F1, PP07F2, PP07F3, PP07F4, PP07F5, PP07G1, PP07G2, PP07G3, PP07G4, PP07G_59, PP07H, PP07I, PP07J, PP07K, PP08D1, PP08D4, PP08F1, PP08F2, PP08J1, PP08J2, ...]
# Index: []
#
# [0 rows x 181 columns]
# Datos originales para 2024:
#  Empty DataFrame
# Columns: [CODUSU, ANO4, TRIMESTRE, NRO_HOGAR, COMPONENTE, H15, REGION, MAS_500, AGLOMERADO, PONDERA, CH03, CH04, CH05, CH06, CH07, CH08, CH09, CH10, CH11, CH12, CH13, CH14, CH15, CH15_COD, CH16, CH16_COD, NIVEL_ED, ESTADO, CAT_OCUP, CAT_INAC, IMPUTA, PP02C1, PP02C2, PP02C3, PP02C4, PP02C5, PP02C6, PP02C7, PP02C8, PP02E, PP02H, PP02I, PP03C, PP03D, PP3E_TOT, PP3F_TOT, PP03G, PP03H, PP03I, PP03J, INTENSI, PP04A, PP04B_COD, PP04B1, PP04B2, PP04B3_MES, PP04B3_ANO, PP04B3_DIA, PP04C, PP04C99, PP04D_COD, PP04G, PP05B2_MES, PP05B2_ANO, PP05B2_DIA, PP05C_1, PP05C_2, PP05C_3, PP05E, PP05F, PP05H, PP06A, PP06C, PP06D, PP06E, PP06H, PP07A, PP07C, PP07D, PP07E, PP07F1, PP07F2, PP07F3, PP07F4, PP07F5, PP07G1, PP07G2, PP07G3, PP07G4, PP07G_59, PP07H, PP07I, PP07J, PP07K, PP08D1, PP08D4, PP08F1, PP08F2, PP08J1, PP08J2, ...]
# Index: []
#
# [0 rows x 181 columns]
# Registros 2004: 0
# Registros 2024: 0
# Composición 2004:
#  Series([], Name: count, dtype: int64)
# Composición 2024:
#  Series([], Name: count, dtype: int64)
# DataFrame de composición:
#  Empty DataFrame
# Columns: [2004, 2024]
# Index: []
# No hay datos para graficar.

# %% [markdown]
# D. Realicen una matriz de correlación para 2004 y 2024 con las siguientes variables: CH04, CH06, CH07, CH08, NIVEL ED, ESTADO, CAT_INAC, IPCF. Utilicen alguno de los comandos disponibles en este link o este link para

# %%
# Imprimir las columnas como una lista para poder ver los nombres de todas
print(list(eph_combined.columns))
# Out:
# ['CODUSU', 'ANO4', 'TRIMESTRE', 'NRO_HOGAR', 'COMPONENTE', 'H15', 'REGION', 'MAS_500', 'AGLOMERADO', 'PONDERA', 'CH03', 'CH04', 'CH05', 'CH06', 'CH07', 'CH08', 'CH09', 'CH10', 'CH11', 'CH12', 'CH13', 'CH14', 'CH15', 'CH15_COD', 'CH16', 'CH16_COD', 'NIVEL_ED', 'ESTADO', 'CAT_OCUP', 'CAT_INAC', 'IMPUTA', 'PP02C1', 'PP02C2', 'PP02C3', 'PP02C4', 'PP02C5', 'PP02C6', 'PP02C7', 'PP02C8', 'PP02E', 'PP02H', 'PP02I', 'PP03C', 'PP03D', 'PP3E_TOT', 'PP3F_TOT', 'PP03G', 'PP03H', 'PP03I', 'PP03J', 'INTENSI', 'PP04A', 'PP04B_COD', 'PP04B1', 'PP04B2', 'PP04B3_MES', 'PP04B3_ANO', 'PP04B3_DIA', 'PP04C', 'PP04C99', 'PP04D_COD', 'PP04G', 'PP05B2_MES', 'PP05B2_ANO', 'PP05B2_DIA', 'PP05C_1', 'PP05C_2', 'PP05C_3', 'PP05E', 'PP05F', 'PP05H', 'PP06A', 'PP06C', 'PP06D', 'PP06E', 'PP06H', 'PP07A', 'PP07C', 'PP07D', 'PP07E', 'PP07F1', 'PP07F2', 'PP07F3', 'PP07F4', 'PP07F5', 'PP07G1', 'PP07G2', 'PP07G3', 'PP07G4', 'PP07G_59', 'PP07H', 'PP07I', 'PP07J', 'PP07K', 'PP08D1', 'PP08D4', 'PP08F1', 'PP08F2', 'PP08J1', 'PP08J2', 'PP08J3', 'PP09A', 'PP09A_ESP', 'PP09B', 'PP09C', 'PP09C_ESP', 'PP10A', 'PP10C', 'PP10D', 'PP10E', 'PP11A', 'PP11B_COD', 'PP11B1', 'PP11B2_MES', 'PP11B2_ANO', 'PP11B2_DIA', 'PP11C', 'PP11C99', 'PP11D_COD', 'PP11G_ANO', 'PP11G_MES', 'PP11G_DIA', 'PP11L', 'PP11L1', 'PP11M', 'PP11N', 'PP11O', 'PP11P', 'PP11Q', 'PP11R', 'PP11S', 'PP11T', 'P21', 'DECOCUR', 'IDECOCUR', 'RDECOCUR', 'GDECOCUR', 'PDECOCUR', 'ADECOCUR', 'PONDIIO', 'TOT_P12', 'P47T', 'DECINDR', 'IDECINDR', 'RDECINDR', 'GDECINDR', 'PDECINDR', 'ADECINDR', 'PONDII', 'V2_M', 'V3_M', 'V4_M', 'V5_M', 'V8_M', 'V9_M', 'V10_M', 'V11_M', 'V12_M', 'V18_M', 'V19_AM', 'V21_M', 'T_VI', 'ITF', 'DECIFR', 'IDECIFR', 'RDECIFR', 'GDECIFR', 'PDECIFR', 'ADECIFR', 'IPCF', 'DECCFR', 'IDECCFR', 'RDECCFR', 'GDECCFR', 'PDECCFR', 'ADECCFR', 'PONDIH', 'PJ1_1', 'PJ2_1', 'PJ3_1', 'IDIMPP']

# %%
# Filtrar los datos para 2004 y 2024
datos_2004 = eph_combined[eph_combined['ANO4'] == '2004'][['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 'CAT_INAC', 'IPCF']]
datos_2024 = eph_combined[eph_combined['ANO4'] == '2024'][['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 'CAT_INAC', 'IPCF']]

# Eliminar filas con NaN
datos_2004.dropna(inplace=True)
datos_2024.dropna(inplace=True)

# Matriz de correlación para 2004
corr_2004 = datos_2004.corr()

# Matriz de correlación para 2024
corr_2024 = datos_2024.corr()

import seaborn as sns
import matplotlib.pyplot as plt

# Configuración del gráfico para 2004
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr_2004, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=True  # Mostrar valores de correlación en la matriz
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
plt.title('Matriz de Correlación - 2004')
plt.show()

# Configuración del gráfico para 2024
plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr_2024, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=True  # Mostrar valores de correlación en la matriz
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
plt.title('Matriz de Correlación - 2024')
plt.show()

# %% [markdown]
# E. ¿Cuántos desocupados hay en la muestra? ¿Cuántos inactivos? ¿Cuál es la media de ingreso per cápita familiar (IPCF) según estado (ocupado, desocupado, inactivo)?

# %%
# Contar los desocupados y ocupados
num_ocupados_04 = eph_04[eph_04['ESTADO'] == 1].shape[0]
num_desocupados_04 = eph_04[eph_04['ESTADO'] == 2].shape[0]
num_inactivos_04 = eph_04[eph_04['ESTADO'] == 3].shape[0]

num_ocupados_24 = eph_24[eph_24['ESTADO'] == 1].shape[0]
num_desocupados_24 = eph_24[eph_24['ESTADO'] == 2].shape[0]
num_inactivos_24 = eph_24[eph_24['ESTADO'] == 3].shape[0]

print(f"2004 - Ocupados: {num_ocupados_04}, Desocupados: {num_desocupados_04}, Inactivos: {num_inactivos_04}")
print(f"2024 - Ocupados: {num_ocupados_24}, Desocupados: {num_desocupados_24}, Inactivos: {num_inactivos_24}")
# Out:
# 2004 - Ocupados: 20325, Desocupados: 1362, Inactivos: 18724
# 2024 - Ocupados: 0, Desocupados: 0, Inactivos: 0

# %%
# Contar los desocupados e inactivos en la muestra total
num_ocupados_total = eph_combined[eph_combined['ESTADO'] == 1].shape[0]
num_desocupados_total = eph_combined[eph_combined['ESTADO'] == 2].shape[0]
num_inactivos_total = eph_combined[eph_combined['ESTADO'] == 3].shape[0]

print(f"Total - Ocupados: {num_ocupados_total}, Desocupados: {num_desocupados_total}, Inactivos: {num_inactivos_total}")

# Media de IPCF por estado en la muestra total
media_ipcf_total = eph_combined.groupby('ESTADO')['IPCF'].mean()

print("Media de IPCF por estado en la muestra total:")
print(media_ipcf_total)
# Out:
# Total - Ocupados: 2278, Desocupados: 0, Inactivos: 0
# Media de IPCF por estado en la muestra total:
# ESTADO
# 1                                                               293874.880246
# Desocupado                                                         224.231970
# Entrevista individual no realizada (no respuesta al cuestion        52.533333
# Inactivo                                                           315.967893
# Menor de 10 años                                                   246.116417
# Ocupado                                                            476.040734
# Name: IPCF, dtype: float64

# %% [markdown]
# 3. ¿Cuántas personas no respondieron cuál es su condición de actividad? Guarden como una base distinta llamada respondieron las observaciones donde respondieron la pregunta sobre su condición de actividad (ESTADO). Las observaciones con ESTADO=0 guárdenlas en una base bajo el nombre norespondieron.

# %%
# Contamos cuántas personas no respondieron
no_respondieron_count = eph_combined[eph_combined['ESTADO'] == 0].shape[0]
print("Cantidad de personas que no respondieron su condición de actividad:", no_respondieron_count)

# Guardamos las observaciones en bases separadas
respondieron = eph_combined[eph_combined['ESTADO'] != 0]  # Filtramos las filas donde 'estado' es diferente de 0
norespondieron = eph_combined[eph_combined['ESTADO'] == 0]  # Filtramos las filas donde 'estado' es igual a 0

# Verificamos el tamaño de cada base para asegurarnos
print("Cantidad de observaciones en 'respondieron':", respondieron.shape[0])
print("Cantidad de observaciones en 'norespondieron':", norespondieron.shape[0])
# Out:
# Cantidad de personas que no respondieron su condición de actividad: 0
# Cantidad de observaciones en 'respondieron': 9790
# Cantidad de observaciones en 'norespondieron': 0

# %% [markdown]
# 4. Agreguen a la base respondieron una columna llamada PEA (Población Económicamente Activa) que tome 1 si están ocupados o desocupados en ESTADO. Realicen un gráfico de barras mostrando la composición por PEA para 2004 y 2024. Comenten los resultados.

# %%
# Crear la columna PEA en 'respondieron' (1 si ocupados o desocupados, 0 en caso contrario)
respondieron['PEA'] = respondieron['ESTADO'].apply(lambda x: 1 if x in [1, 2] else 0)

# Filtrar por año para obtener datos de 2004 y 2024
respondieron_2004 = respondieron[respondieron['ANO4'] == '2004']
respondieron_2024 = respondieron[respondieron['ANO4'] == '2024']

# Contar la cantidad de personas en PEA y no PEA para cada año
pea_2004 = respondieron_2004['PEA'].value_counts()
pea_2024 = respondieron_2024['PEA'].value_counts()

# Crear un DataFrame para facilitar la visualización
df_pea = pd.DataFrame({
    '2004': pea_2004,
    '2024': pea_2024
}).fillna(0)  # Rellenar valores NaN con 0 si falta alguna categoría

# Verificar la estructura del DataFrame
print(df_pea)

# Graficar la composición por PEA para 2004 y 2024
df_pea.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'salmon'])
plt.title('Composición de la Población Económicamente Activa (PEA) en 2004 y 2024')
plt.xlabel('PEA (1 = Económicamente Activo, 0 = No Activo)')
plt.ylabel('Cantidad de Personas')
plt.xticks(ticks=[0, 1], labels=['No Activo', 'Económicamente Activo'], rotation=0)
plt.legend(title='Año')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Empty DataFrame
# Columns: [2004, 2024]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[128], line 22
#      19 print(df_pea)
#      21 # Graficar la composición por PEA para 2004 y 2024
# ---> 22 df_pea.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'salmon'])
#      23 plt.title('Composición de la Población Económicamente Activa (PEA) en 2004 y 2024')
#      24 plt.xlabel('PEA (1 = Económicamente Activo, 0 = No Activo)')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\core.py:508, in MPLPlot.generate(self)
#     506 for ax in self.axes:
#     507     self._post_plot_logic_common(ax)
# --> 508     self._post_plot_logic(ax, self.data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1966, in BarPlot._post_plot_logic(self, ax, data)
#    1963 else:
#    1964     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 1966 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1967 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1969 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
